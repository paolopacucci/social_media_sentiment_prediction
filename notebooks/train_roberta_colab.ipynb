# %%
### TRAINING INIZIALE DEL MODELLO CON GPU

# %%
# 1. Clonazione della repository GitHub

# !git clone https://github.com/paolopacucci/social_media_sentiment_prediction.git
# %cd /content/social_media_sentiment_prediction

# %%
# 2. Installazione dependencies

# !python -m pip install --upgrade pip
# !pip install -r requirements-colab.txt

# %%
# 3. Inserimento del token Hugging Face

import os
import getpass

os.environ["HF_TOKEN"] = getpass.getpass("HF token: ")

# %%
# 4. Avvio del training iniziale

# !python -m src.training.train_roberta_colab
# Out:
# 2026-03-03 15:06:36.536030: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1772550396.704076    2150 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1772550396.749351    2150 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1772550397.082901    2150 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# 5. Verifica degli output prodotti

# %cd /content/social_media_sentiment_prediction
# !pwd
# !git status
# Out:
# /content/social_media_sentiment_prediction
# /content/social_media_sentiment_prediction
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	data/preprocessed/
# 	data/split/
# 	reports/
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# 6. Push su GitHub da Colab

# %%
# !git config user.name "Paolo Pacucci"
# !git config user.email "paolopacucciai@gmail.com"

# %%
# !git add -f data/preprocessed/sentiment_preprocessed.csv data/split/train/train.csv data/split/train/val.csv data/split/shared/test.csv reports/train/final_metrics.json

# %%
# !git commit -m "Aggiunta file preporcessed, split e training report"
# Out:
# [main 3968d55] Add shared benchmark split and training report
#  5 files changed, 62955 insertions(+)
#  create mode 100644 data/preprocessed/sentiment_preprocessed.csv
#  create mode 100644 data/split/shared/test.csv
#  create mode 100644 data/split/train/train.csv
#  create mode 100644 data/split/train/val.csv
#  create mode 100644 reports/train/final_metrics.json

# %%
import getpass
GITHUB_PAT = getpass.getpass("GitHub PAT: ")
# Out:
# GitHub PAT: ··········

# %%
import subprocess

repo_url = f"https://paolopacucci:{GITHUB_PAT}@github.com/paolopacucci/social_media_sentiment_prediction.git"

subprocess.run(["git", "remote", "set-url", "origin", repo_url], check=True)
subprocess.run(["git", "push", "origin", "main"], check=True)
# Out:
# CompletedProcess(args=['git', 'push', 'origin', 'main'], returncode=0)

# %%
# !git remote set-url origin https://github.com/paolopacucci/social_media_sentiment_prediction.git
